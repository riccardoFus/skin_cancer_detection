# %% [markdown]
# # Import needed libraries

# %%
# import system libs 
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras import regularizers
from tensorflow.keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# ### Read data

# %%
data_dir = "C:\\Users\\fusyr\\OneDrive\\Documenti\\Riccardo\\Progetti\\skin-cancer-detection-cnn\\multi class classifier\\archive\\hmnist_28_28_RGB.csv"
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### Split data and labels

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %% [markdown]
# ### Handling imbalanced datasets

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6])

# %% [markdown]
# ### Convert abbreviations to it's words

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2 :('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ### Splitting train and test

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(f'X_train shape: {X_train.shape}\nX_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}\ny_test shape: {y_test.shape}')
# Out:
# X_train shape: (35201, 28, 28, 3)
# X_test shape: (11734, 28, 28, 3)
# y_train shape: (35201,)
# y_test shape: (11734,)

# %% [markdown]
# ### Convert labels to categorical types

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Create Image Data Generation

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %% [markdown]
# ### Create ReduceLROnPlateau to learning rate reduction

# %%
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %% [markdown]
# # Model Structure

# %%
model = keras.models.Sequential()

# Create Model Structure
model.add(keras.layers.Input(shape=[28, 28, 3]))
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())

model.add(keras.layers.Flatten())

model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=256, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=128, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=64, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=32, activation='relu', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.L1L2()))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=7, activation='softmax', kernel_initializer='glorot_uniform', name='classifier'))

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 14, 14, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 14, 14, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 7, 7, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 7, 7, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 7, 7, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 3, 3, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 3, 3, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 3, 3, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ classifier (Dense)                   │ (None, 7)                   │             231 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,275,079 (4.86 MB)
#  Trainable params: 1,273,671 (4.86 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %% [markdown]
# ### Training model

# %%
history = model.fit(X_train ,
                    y_train ,
                    epochs=25 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 96s 320ms/step - accuracy: 0.3789 - loss: 1.6551 - val_accuracy: 0.5867 - val_loss: 1.0937 - learning_rate: 0.0010
# Epoch 2/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 84s 303ms/step - accuracy: 0.7555 - loss: 0.7227 - val_accuracy: 0.8625 - val_loss: 0.4048 - learning_rate: 0.0010
# Epoch 3/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 84s 303ms/step - accuracy: 0.8765 - loss: 0.3738 - val_accuracy: 0.9068 - val_loss: 0.2672 - learning_rate: 0.0010
# Epoch 4/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 152s 340ms/step - accuracy: 0.9231 - loss: 0.2316 - val_accuracy: 0.9215 - val_loss: 0.2272 - learning_rate: 0.0010
# Epoch 5/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 144s 346ms/step - accuracy: 0.9436 - loss: 0.1693 - val_accuracy: 0.9345 - val_loss: 0.1888 - learning_rate: 0.0010
# Epoch 6/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 141s 341ms/step - accuracy: 0.9585 - loss: 0.1232 - val_accuracy: 0.9345 - val_loss: 0.1780 - learning_rate: 0.0010
# Epoch 7/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 140s 334ms/step - accuracy: 0.9732 - loss: 0.0836 - val_accuracy: 0.9517 - val_loss: 0.1481 - learning_rate: 0.0010
# Epoch 8/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 144s 342ms/step - accuracy: 0.9742 - loss: 0.0761 - val_accuracy: 0.9335 - val_loss: 0.2054 - learning_rate: 0.0010
# Epoch 9/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 141s 336ms/step - accuracy: 0.9801 - loss: 0.0596 - val_accuracy: 0.9749 - val_loss: 0.0805 - learning_rate: 0.0010
# Epoch 10/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 127s 283ms/step - accuracy: 0.9858 - loss: 0.0438 - val_accuracy: 0.9460 - val_loss: 0.1652 - learning_rate: 0.0010
# Epoch 11/25
# 275/276 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9862 - loss: 0.0418
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 78s 283ms/step - accuracy: 0.9862 - loss: 0.0418 - val_accuracy: 0.9738 - val_loss: 0.0963 - learning_rate: 0.0010
# Epoch 12/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 80s 291ms/step - accuracy: 0.9951 - loss: 0.0185 - val_accuracy: 0.9839 - val_loss: 0.0647 - learning_rate: 5.0000e-04
# Epoch 13/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 79s 287ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.9837 - val_loss: 0.0692 - learning_rate: 5.0000e-04
# Epoch 14/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 89s 322ms/step - accuracy: 0.9979 - loss: 0.0073 - val_accuracy: 0.9855 - val_loss: 0.0624 - learning_rate: 5.0000e-04
# Epoch 15/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 136s 300ms/step - accuracy: 0.9984 - loss: 0.0061 - val_accuracy: 0.9823 - val_loss: 0.0836 - learning_rate: 5.0000e-04
# Epoch 16/25
# 275/276 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9985 - loss: 0.0060
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 141s 298ms/step - accuracy: 0.9985 - loss: 0.0060 - val_accuracy: 0.9856 - val_loss: 0.0654 - learning_rate: 5.0000e-04
# Epoch 17/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 142s 299ms/step - accuracy: 0.9990 - loss: 0.0041 - val_accuracy: 0.9835 - val_loss: 0.0772 - learning_rate: 2.5000e-04
# Epoch 18/25
# 275/276 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9993 - loss: 0.0031
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 147s 315ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.9836 - val_loss: 0.0783 - learning_rate: 2.5000e-04
# Epoch 19/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 141s 311ms/step - accuracy: 0.9998 - loss: 0.0020 - val_accuracy: 0.9852 - val_loss: 0.0666 - learning_rate: 1.2500e-04
# Epoch 20/25
# 275/276 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9998 - loss: 0.0015
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 142s 312ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.9844 - val_loss: 0.0754 - learning_rate: 1.2500e-04
# Epoch 21/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 139s 301ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9853 - val_loss: 0.0682 - learning_rate: 6.2500e-05
# Epoch 22/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 143s 304ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9859 - val_loss: 0.0675 - learning_rate: 6.2500e-05
# Epoch 23/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 79s 285ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.9853 - val_loss: 0.0712 - learning_rate: 6.2500e-05
# Epoch 24/25
# 275/276 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9999 - loss: 0.0011
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 85s 296ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9853 - val_loss: 0.0707 - learning_rate: 6.2500e-05
# Epoch 25/25
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 88s 317ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9858 - val_loss: 0.0689 - learning_rate: 3.1250e-05

# %% [markdown]
# ### Show training history

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %% [markdown]
# # Model Evaluation

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 1.0000 - loss: 1.1967e-04
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9834 - loss: 0.0796
# Train Loss:  0.00012034123210469261
# Train Accuracy:  1.0
# --------------------
# Test Loss:  0.06890977174043655
# Test Accuracy:  0.9857678413391113

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step

# %% [markdown]
# ### Create classes labels

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %% [markdown]
# ### Confussion Matrix

# %%
# Confusion matrix
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %% [markdown]
# ### Save model

# %%
#Save the model
model.save('Skin Cancer.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Convert model to tflite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model) 
tflite_model = converter.convert() 

print("model converted")

# Save the model. 
with open('Skin.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\fusyr\AppData\Local\Temp\tmpz9f5qkxb\assets
# INFO:tensorflow:Assets written to: C:\Users\fusyr\AppData\Local\Temp\tmpz9f5qkxb\assets
# Saved artifact at 'C:\Users\fusyr\AppData\Local\Temp\tmpz9f5qkxb'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   2914689187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914689186896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698772752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698773904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914689187088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698773328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698774672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698776208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698776592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698776976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698777744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698778128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698775440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698774864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698779280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698779664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698779856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698780816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698781584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698781968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698780048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698780432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698783120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698783504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698782352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698784272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698785232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698786768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698788496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698787536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698787728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914698785424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685093072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685094608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685096144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685096720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685095760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685095376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685098064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685099600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685100944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685101520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685100560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685098256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685103248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685104592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685106320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685106896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685105936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685104976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685107856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2914685106704: TensorSpec(shape=(), dtype=tf.resource, name=None)
# model converted
